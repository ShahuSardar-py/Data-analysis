# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Reading the dataset

# %%
df= pd.read_csv('D:\Python\My projects\Sales analysis\Python_Diwali_Sales_Analysis\Diwali Sales Data.csv', encoding='unicode_escape')
df.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# ## Describing the data

# %%
df.shape
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# # The colums "Status" and "unnamed" has null values.

# %%
#Cleaning the null columns 
df.drop(['Status', 'unnamed1'], axis= 1, inplace= True )
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %% [markdown]
# # Finding the null values in the colums

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# # Amount has 12 null values

# %%
df.dropna(inplace= True)
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
df['Amount']= df['Amount'].astype(int)
df['Amount'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# ## EDA

# %% [markdown]
# # Gender

# %%
ax= sns.countplot(x= 'Gender', data= df, palette=['#ff6680',"#0000ff"])

for bars in ax.containers:
    ax.bar_label(bars)

# %%
amount_spent= df.groupby(['Gender'], as_index= False)['Amount'].sum().sort_values(by='Amount', ascending= False)
sns.barplot(x= 'Gender', y= 'Amount', data= amount_spent)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %% [markdown]
# ###Female population spent more

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender', palette=['#ff6680',"#0000ff"])

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# ### Most purchases by females of the age group 26-35

# %% [markdown]
# # State

# %%
sns.set(rc={'figure.figsize':(20,5)})
sales_state= df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)

sns.barplot(data = sales_state, x = 'State', y= 'Orders')
# Out:
# <Axes: xlabel='State', ylabel='Orders'>

# %% [markdown]
# ### Most number of orders from Uttar pradesh

# %%
amount_states= df.groupby(['State'], as_index= False)['Amount'].sum().sort_values(by= 'Amount', ascending= False)
sns.barplot(data= amount_states, x= 'State', y= 'Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %% [markdown]
# # Occupation

# %%
occupation= df.groupby(['Occupation'], as_index= False)['Orders'].sum().sort_values(by= 'Orders', ascending= False)
sns.barplot(data= occupation, x= 'Occupation', y= 'Orders')
# Out:
# <Axes: xlabel='Occupation', ylabel='Orders'>

# %%
df.groupby('Product_Category').count()['User_ID']
# Out:
# Product_Category
# Auto                       97
# Beauty                    422
# Books                     103
# Clothing & Apparel       2655
# Decor                      96
# Electronics & Gadgets    2087
# Food                     2490
# Footwear & Shoes         1059
# Furniture                 352
# Games & Toys              386
# Hand & Power Tools         26
# Household items           520
# Office                    113
# Pet Care                  212
# Sports Products           356
# Stationery                112
# Tupperware                 72
# Veterinary                 81
# Name: User_ID, dtype: int64

# %%
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data = df, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# # Conclusion

# %% [markdown]
# ### Highest number of oders were ordered by females of the age 26-35 from IT sector and most amount was spent on Clothing and apprales.
